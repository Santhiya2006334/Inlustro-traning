# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhiya2006334/Inlustro-traning/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=30
y="santhiya"
print(x)
print(y)
# Out:
# 30
# santhiya

# %%
a=102
b=12
c=a+b;
print(c)
# Out:
# 114

# %%
price=0.5
print(price)
# Out:
# 0.5

# %%
is_vaild=True
print(is_vaild)
# Out:
# True

# %%
x=10
y=20
z=30
print(x,y,z)
# Out:
# 10 20 30

# %%
p=100
q=100
r=100
print(p)
print(q)
print(r)
# Out:
# 100
# 100
# 100

# %%
value=123
del value

# %%
age=25
print(age)
age=30
print(age)
# Out:
# 25
# 30

# %%
message="santhiya"
print(len (message))
# Out:
# 8

# %%
data=45
print("initial value:",data)
data="santhiya"
print=("change value:",data)
# Out:
# initial value: 45

# %%
num=8
if num>0:
 print("positive")
# Out:
# positive

# %%
age=20
if age>=18:
  print("Eligible to vote")
else:
  print("not eligible to vote")
# Out:
# Eligible to vote

# %%
num=5
if num>0:
  print("positive")
elif(num<0):
    print("negative")
else:
      print("Zero")
# Out:
# positive

# %%
num=8
if num%2==0:
  print("even")
else:
  print("Odd")
# Out:
# even

# %%
num=8
if num>0:
  if num%2==0:
    print("positive and even")
# Out:
# positive and even

# %%
x=10
if x==10:
  print("python is cool")
# Out:
# python is cool

# %%
num=12
print("even"if num%2==0 else "odd")
# Out:
# even

# %%
text ="I Love Python Programming"
if 'Python'in text:
    print("String contains python")
# Out:
# String contains python

# %%
num=19
if num% 3==0 and num %5==0:
  print("Divisible by both 3 and 5")
else:
    print("not divisible by both 3 and 5")
# Out:
# not divisible by both 3 and 5

# %%
year=2025
if(year%4==0 and year%100!=0)or(year%400==0):
  print("leap year")
else:
  print("not a leap year")
# Out:
# not a leap year
