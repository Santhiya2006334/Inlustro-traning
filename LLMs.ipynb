# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhiya2006334/Inlustro-traning/blob/main/LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyBHofKE1C89XfyWcbvXSSoQc-vJFx98D0M")
model=GenerativeModel("gemini-1.5-pro")
r=model.generate_content("who are you")
print(r.text)
# Out:
# I am a large language model, trained by Google.

# %%
from google.generativeai import GenerativeModel, configure
configure(api_key="AIzaSyBHofKE1C89XfyWcbvXSSoQc-vJFx98D0M")
model=GenerativeModel("gemini-1.5-pro")
print("Welcome to AI Chatbot!Type'exit' to stop.")
while True:
    user_input=input("you:")
    if user_input.lower() =="exit":
          break
    response=model.generate_content(user_input)
    print("AI:", response. text)
# Out:
# Welcome to AI Chatbot!Type'exit' to stop.
# AI: Sindhu is traditionally a girl's name.  It's of Sanskrit origin, meaning "river" or "ocean."  While it's *possible* someone might give it to a boy, it's overwhelmingly used for girls.
#
# AI: Kabaddi is a contact team sport, popular in South Asia.  Two teams of seven players each face off in a rectangular court. The objective is for a single player on offense, called a "raider," to run into the opposing team's half of the court, tag out as many of their defenders as possible, and return to their own half of the court, all without inhaling.
#
# Here's a breakdown of key elements:
#
# * **The Raid:** The raider must continuously chant "kabaddi, kabaddi, kabaddi..." (or an equivalent approved word) while in the opponent's half, proving they are not inhaling.  This chant is the source of the sport's name.
# * **Tagging:**  The raider must tag members of the opposing team with any part of their body (hand, foot, torso, etc.).
# ...

# %%
# !pip install deep_translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
def translate_text(text, target_language):
    translator=GoogleTranslator (source='auto',target=target_language)
    return translator.translate(text)
text="I love you"
target_language="ta"

translated_text=translate_text(text, target_language)
print(f"Original:{text}")
print(f"Translated({target_language}) :{translated_text}")
# Out:
# Original:I love you
# Translated(ta) :நான் உன்னை நேசிக்கிறேன்
